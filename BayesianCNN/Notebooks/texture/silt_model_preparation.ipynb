# %%
from ray.tune.search.bayesopt import BayesOptSearch
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler
import copy
import numpy as np
import pandas as pd
import os
import torch
import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
from torch.distributions import Normal, beta
from torch.utils.data import DataLoader
from torchmetrics.regression import R2Score
# Out:
# C:\Users\omondiagbep\Anaconda3\envs\pytorch\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\omondiagbep\Anaconda3\envs\pytorch\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\omondiagbep\Anaconda3\envs\pytorch\lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# C:\Users\omondiagbep\Anaconda3\envs\pytorch\lib\site-packages\torchaudio\backend\utils.py:74: UserWarning: No audio backend is available.
#   warnings.warn("No audio backend is available.")

# %%
PREDICT_PROPERTIES=['silt']


def get_spectra_data(train_csv, test_csv=None,mineral=False,target_dataframe=None,over_write_csv=False):


    SPECTRA_COLUMN_STARTING = "nir."
    ID=['labSampleId']

    # check if this is a target and make the target csv to be the same with the global file used for training
    if isinstance(train_csv, list):
        df_source = pd.concat(map(pd.read_csv, train_csv), ignore_index=True)
        #remove spectra signal which is more than 1
        print("removing out of bound spectra from source")

        #subset only the mineral from the lucas data
        if mineral:
            reflectance_out_of_bound = df_source.loc[df_source[df_source[df_source.columns[pd.Series(df_source.columns).str.startswith(SPECTRA_COLUMN_STARTING)]] > 1].dropna(
            how='all', axis=0).index]
            df_source = df_source.loc[set(df_source.index) - set(reflectance_out_of_bound.index)]

            if 'mineral' in df_source.columns:
                df_source=df_source.loc[df_source['mineral'] == 'mineral']


    if target_dataframe is not None:
        df_target = target_dataframe

    if isinstance(test_csv, list) and target_dataframe is None:
        df_target = pd.concat(map(pd.read_csv, test_csv), ignore_index=True)

        # remove spectra signal which is more than 1
        print("removing out of bound spectra from target")

        if mineral:
            reflectance_out_of_bound = df_target.loc[df_target[df_target[df_target.columns[
                pd.Series(df_target.columns).str.startswith(SPECTRA_COLUMN_STARTING)]] > 1].dropna(
                how='all', axis=0).index]

            df_target = df_target.loc[set(df_target.index) - set(reflectance_out_of_bound.index)]

    #common_cols = list(set.intersection(set(df_target), set(df_source)))
    #print(common_cols)

    common_cols = df_source.columns.intersection(df_target.columns)

    # use this list to perform column selection
    df_target_ = df_target[common_cols]
    df_source_ = df_source[common_cols]


    # extract properties for source and target
    df_source_ = df_source_.filter(regex='^(nir.|silt|labSampleId)')
    df_target_ = df_target_.filter(regex='^(nir.|silt|labSampleId)')



    # Define the character to remove
    character_to_remove = 'nir.'

    # Remove the character from column names
    df_source_.columns = df_source_.columns.str.replace(character_to_remove, '')
    df_target_.columns = df_target_.columns.str.replace(character_to_remove, '')


    # Extract column names with numbers greater than the threshold
    source_columns_to_drop = [col for col in df_source_.filter(regex='^(nir.)').columns if int(col) > 4000]
    target_columns_to_drop = [col for col in df_target_.filter(regex='^(nir.)').columns if int(col) > 4000]

    # Drop the selected columns from the DataFrame
    df_source_ = df_source_.drop(columns=source_columns_to_drop)
    df_target_ = df_target_.drop(columns=target_columns_to_drop)


    #split train datasest into train and amin_val_loss
    from sklearn.model_selection import train_test_split
    df_source_train, df_source_val= train_test_split(df_source_,  test_size=0.2, random_state=42)



    df_source_train_= df_source_train.drop(columns=PREDICT_PROPERTIES)
    df_source_val_= df_source_val.drop(columns=PREDICT_PROPERTIES)
    df_target__= df_target_.drop(columns=PREDICT_PROPERTIES)

    df_source_spectral_train = get_spectra(df_source_train_)

    df_source_spectral_val = get_spectra(df_source_val_)
    print(len(df_source_spectral_train))
    print(len(df_source_spectral_val))


    df_target_spectral = get_spectra(df_target__)
    print(len(df_target_spectral))

    if over_write_csv:
        pd.DataFrame(df_source_spectral_train).head(2).to_csv("../Data/silt_source_file.csv", index=False)

    df_source_spectral_train=df_source_spectral_train.to_numpy()
    df_source_spectral_val=df_source_spectral_val.to_numpy()
    df_target_spectral=df_target_spectral.to_numpy()

    print(df_source_spectral_train.shape)

    for i in range(len(PREDICT_PROPERTIES)):
        if PREDICT_PROPERTIES[i] not in df_source_train.columns:
            df_source_train[PREDICT_PROPERTIES[i]] =df_source_train[PREDICT_PROPERTIES[i]]

        if PREDICT_PROPERTIES[i] not in df_source_val.columns:
            df_source_val[PREDICT_PROPERTIES[i]] =df_source_val[PREDICT_PROPERTIES[i]]

        if PREDICT_PROPERTIES[i] not in df_target_.columns and PREDICT_PROPERTIES[i] in  df_target:
            df_target_[PREDICT_PROPERTIES[i]] =df_target[PREDICT_PROPERTIES[i]]

    # remove the 2500 column in the USA/NZ data
    #df_source = df_source.drop([SPECTRA_COLUMN_STARTING, SPECTRA_COLUMN_STARTING + '2500'], axis=1, errors='ignore')
    #df_target = df_target.drop([SPECTRA_COLUMN_STARTING, SPECTRA_COLUMN_STARTING + '2500'], axis=1, errors='ignore')

    return df_source_train, df_source_val,df_target_, df_source_spectral_train,df_source_spectral_val, df_target_spectral


def get_spectra(df):

    filter_col = [col for col in df.columns]

    data = df[filter_col]

    data=data.iloc[:, 2::10]


    return data

# %%
import pandas as pd
GLOBAL_CSV=[ "C:/Projects/SmapProjects/SpectraData2023/mir_texture_cali.csv"]
#df_sources, df_targets, df_sources_spectral, df_targets_spectral=get_spectra_data(train_csv=GLOBAL_CSV,target_dataframe=df)

TARGET_CSV=[ "C:/Projects/SmapProjects/SpectraData2023/mir_texture_val.csv"]
df_source_train, df_source_val,df_target, df_source_spectral_train, df_source_spectral_val,df_target_spectral=get_spectra_data(train_csv=GLOBAL_CSV,test_csv=TARGET_CSV,over_write_csv=True)


X_train_raw = df_source_spectral_train#.reshape(df_source_spectral_train.shape[0], df_source_spectral_train.shape[1], 1)
#X_train=np.log(1 / X_train)
y_train = np.array(df_source_train[PREDICT_PROPERTIES].values)

X_val_raw = df_source_spectral_val#.reshape(df_source_spectral_val.shape[0], df_source_spectral_val.shape[1], 1)
y_val= np.array(df_source_val[PREDICT_PROPERTIES].values)


X_test_raw =df_target_spectral#.reshape(df_target_spectral.shape[0], df_target_spectral.shape[1], 1)
y_test =df_target[PREDICT_PROPERTIES].values
# Out:
# removing out of bound spectra from source
# removing out of bound spectra from target
# 2412
# 604
# 1005
# (2412, 340)

# %%
df_source_val
# Out:
#      labSampleId       silt      4000      3999      3998      3997      3996  \
# 63      SB10134B  68.930000 -0.074913 -0.075331 -0.075767 -0.076227 -0.076636
# 2808    SB09894C  32.790001 -0.047917 -0.047805 -0.047687 -0.047565 -0.047452
# 102     SB09842E  27.389999 -0.076082 -0.079010 -0.082063 -0.085302 -0.088164
# 2692    SB09745B  29.740002 -0.110468 -0.111472 -0.112524 -0.113588 -0.114633
# 416     M18/0291  58.000000 -0.083878 -0.084949 -0.086063 -0.087265 -0.088286
# ...          ...        ...       ...       ...       ...       ...       ...
# 283     M17/7911  54.000000 -0.090098 -0.090718 -0.091368 -0.092011 -0.092674
# 231     M18/0811  54.000000 -0.080462 -0.081107 -0.081777 -0.082507 -0.083111
# 637     SB09963C  73.962997 -0.085436 -0.085541 -0.085652 -0.085755 -0.085874
# 1034    SB10004E  62.555000 -0.036036 -0.037472 -0.038972 -0.040534 -0.041974
# 96      SB09652A  47.530003 -0.094164 -0.093897 -0.093617 -0.093330 -0.093056
#
#           3995      3994      3993  ...       609       608       607  \
# 63   -0.076476 -0.074446 -0.069726  ... -2.907370 -2.949399 -2.862831
# 2808 -0.047326 -0.047063 -0.046522  ...  0.603775  0.605955  0.611350
# 102  -0.090187 -0.092096 -0.093131  ... -2.526272 -2.665675 -2.753467
# 2692 -0.115279 -0.114402 -0.111095  ... -0.468744 -0.444032 -0.424865
# 416  -0.088509 -0.087096 -0.083157  ... -2.701379 -2.822400 -2.850712
# ...        ...       ...       ...  ...       ...       ...       ...
# 283  -0.093187 -0.092868 -0.091343  ... -2.656169 -2.794697 -2.843566
# 231  -0.083062 -0.081519 -0.077925  ... -2.980524 -3.094550 -3.129518
# 637  -0.085871 -0.085200 -0.083394  ... -2.115041 -2.256682 -2.295815
# 1034 -0.043056 -0.043747 -0.043782  ... -2.354397 -2.438833 -2.449846
# 96   -0.092578 -0.091154 -0.088506  ... -2.753741 -2.927823 -3.028015
#
#            606       605       604       603       602       601       600
# 63   -2.670668 -2.419237 -2.119185 -1.775398 -1.428811 -1.094719 -0.778498
# 2808  0.621533  0.637356  0.658497  0.683174  0.708055  0.732013  0.754703
# 102  -2.788477 -2.773178 -2.718126 -2.641012 -2.563073 -2.489146 -2.418586
# 2692 -0.412824 -0.407294 -0.409310 -0.418121 -0.427112 -0.435122 -0.443024
# 416  -2.786940 -2.651300 -2.450232 -2.197872 -1.943115 -1.699641 -1.468165
# ...        ...       ...       ...       ...       ...       ...       ...
# 283  -2.806568 -2.702206 -2.539186 -2.332690 -2.124212 -1.925092 -1.735724
# 231  -3.083343 -2.969656 -2.795273 -2.575735 -2.354108 -2.142313 -1.940948
# 637  -2.241302 -2.119427 -1.941005 -1.719844 -1.496625 -1.283015 -1.080069
# 1034 -2.392724 -2.285748 -2.135217 -1.950689 -1.764472 -1.586103 -1.416722
# 96   -3.050720 -3.002509 -2.892837 -2.742251 -2.590065 -2.445654 -2.307850
#
# [604 rows x 3403 columns]

# %%
# Standardizing data
scaler = StandardScaler()
scaler.fit(X_train_raw)
X_train = scaler.transform(X_train_raw)
scaler.fit(X_val_raw)
X_val = scaler.transform(X_val_raw)

X_test = X_test_raw

# Convert to 2D PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32).reshape(-1, 1)
X_val = torch.tensor(X_val, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32).reshape(-1, 1)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32).reshape(-1, 1)

# %%
def evaluate(model,test_x,test,type="mae",sample_size = 100):
    df =evaluate_soil_property(model,test_x,sample_size = sample_size)

    result_total_pret= pd.DataFrame(columns=['upper', 'lower','pred', 'obs'])

    result_total_pret['pred'] = df['pred']

    result_total_pret['lower'] =df['lower']
    result_total_pret['upper'] =df['upper']

    result_total_pret['obs']=test[:,0]

    if type=="mae":
        r2_total_pret =mean_absolute_error(test[:,0],result_total_pret['pred'])
    elif type=="r2":
        r2_total_pret =r2_score(test[:,0],result_total_pret['pred'])
    elif type=="mse":
        r2_total_pret =mean_squared_error(test[:,0],result_total_pret['pred'])
    elif type=="rmse":
        r2_total_pret=np.sqrt(mean_squared_error(test[:,0],result_total_pret['pred']))


    return r2_total_pret


from scipy.stats import norm
def evaluate_soil_property(model,
                         test,
                        sample_size = 100):

     df = pd.DataFrame(columns=['lower','upper','pred'])

     with torch.no_grad():

        model.eval()
        scaler = StandardScaler()
        scaler.fit(test)
        predictions=[]
        test = scaler.transform(test)
        test = torch.tensor(test, dtype=torch.float32)
        for _ in range(sample_size):

            output = model(test)  # Replace 'input_data' with your test input
            predictions.append(output.numpy())

        predictions = torch.tensor(predictions)

        prediction_mean = (torch.mean(predictions, dim=0)).detach().numpy()


        prediction_std = torch.std(predictions, dim=0).detach().numpy()

        # Calculate lower and upper bounds for the prediction interval (e.g., 95% interval)
        lower_bound_ = prediction_mean - (1.645 * prediction_std)
        upper_bound_ = prediction_mean + (1.645 * prediction_std)


        for i in range(0,len(prediction_mean)):

            #get the first element since we ar predicting just one at a time
            sample_pred = prediction_mean[i][0]

            lower_bound = lower_bound_[i][0]
            upper_bound = upper_bound_[i][0]

            # Check and adjust upper bound if greater than 100
            upper_bound = min(upper_bound, 99.9)

            # Check and adjust prediction if greater than 100
            sample_pred = min(sample_pred, 99.5)

            row = {'upper':upper_bound,'lower':abs(lower_bound),'pred':sample_pred}

            df.loc[i] = row
        return df

# %% [markdown]
# ## 2. Define Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Normal,Uniform



class BayesianCNN(nn.Module):
    def __init__(self, num_feature: int, dims=[512, 28, 64], bias_mean=0.0003,weight_mean=0.0002,weight_std=0.0001, bias_std=0.0005):
        super(BayesianCNN, self).__init__()

        # Define the fully connected layers based on the specified dimensions
        self.fc_layers = nn.ModuleList()
        in_dim = num_feature
        for out_dim in dims:
            self.fc_layers.append(nn.Linear(in_dim, out_dim))
            in_dim = out_dim

        self.fc_out = nn.Linear(in_dim, 1)  # Output layer for pret

        # Update the dimensions of weight_mu and weight_rho to match the output dimension
        self.weight_dim = out_dim
        self.weight_mu = nn.Parameter(torch.Tensor(1, self.weight_dim))
        self.weight_rho = nn.Parameter(torch.Tensor(1, self.weight_dim))

        self.bias_mu = nn.Parameter(torch.Tensor(1))
        self.bias_rho = nn.Parameter(torch.Tensor(1))
        self.weight_std = weight_std
        self.bias_std = bias_std
        self.weight_mean = weight_mean
        self.bias_mean = bias_mean

        # Initialize parameters
        self.reset_parameters()

    def reset_parameters(self):
        # Initialize weight means close to zero and standard deviations to be small
        nn.init.normal_(self.weight_mu, self.weight_mean, std=self.weight_std)
        nn.init.normal_(self.weight_rho, self.weight_mean, std=self.weight_std)

        # Initialize bias means close to zero and standard deviations to be small
        nn.init.normal_(self.bias_mu, self.bias_mean, std=self.bias_std)
        nn.init.normal_(self.bias_rho, self.bias_mean, std=self.bias_std)

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten the input

        # Pass through fully connected layers with specified dimensions
        for fc_layer in self.fc_layers:
            x = F.rrelu(fc_layer(x))
            #Dropout randomly deactivates a fraction of neurons during training,
            # which can help prevent overfitting.
            #x = F.dropout(x,p=0.30)


        # Re-parameterization trick for sampling weights
        #To reduce variability, you can reduce the standard deviation of this sampling.
        weight_epsilon = Normal(0.0,1).sample(self.weight_mu.size())
        weight_sigma = torch.log(1 + torch.exp(self.weight_rho))
        weight = self.weight_mu + (weight_sigma * weight_epsilon)

        bias_epsilon = Normal(0.0,1).sample(self.bias_mu.size())
        bias_sigma = torch.log(1 + torch.exp(self.bias_rho))
        bias = self.bias_mu + (bias_sigma * bias_epsilon)

        # Enforce non-negativity on weights and biases
        weight = torch.clamp(weight, min=0)
        bias = torch.clamp(bias, min=0)


        # Final linear layer operation
        output = F.linear(x, weight, bias)
        # Apply sigmoid activation to squash values between 0 and 1
        #output = torch.sigmoid(output)

        # Scale the values to the desired range (0 to 100)
        #output = output * 100

        return output

# %%
train = torch.utils.data.TensorDataset(X_train,y_train)
train_dataloader = DataLoader(train, batch_size=16)

val= torch.utils.data.TensorDataset(X_val,y_val)
val_dataloader = DataLoader(val, batch_size=16)

test= torch.utils.data.TensorDataset(X_test,y_test)
test_dataloader = DataLoader(test, batch_size=16)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")

#Manually compute the L1 loss over all model parameters:
def l1_penalty(model):
    l1_loss = 0.0
    for param in model.parameters():
        l1_loss += torch.abs(param).sum()
    return l1_loss

def train_epoch(train,val,model,loss_fn,optimizer,batch_size,n_epochs):

    train_dataloader = DataLoader(train, batch_size=batch_size)
    model.train()
    for epoch in range(n_epochs):
        for inputs, targets in train_dataloader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = loss_fn(outputs, targets)
            loss.backward()
            optimizer.step()

        # Print the training loss for this epoch
        print(f"Epoch [{epoch+1}/{n_epochs}] Loss: {loss.item():.5f}")
        #evaluate accuracy at end of each epoch
        test_epoch(val,model, loss_fn ,optimizer,batch_size,n_epochs)


def test_epoch(val,model,loss_fn,optimizer,batch_size,n_epochs):
    val_dataloader = DataLoader(val, batch_size=batch_size)
    val_loss=0
    model.eval()
    for inputs, targets in val_dataloader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = loss_fn(outputs, targets)
            val_loss += loss.item()
            loss.backward()
            optimizer.step()

        # Print the training loss for this epoch
    avg_val_loss = val_loss / len(inputs)
    print(f"Epoch [{n_epochs+1}/{n_epochs}] Val Loss: {loss.item():.5f}")


    return avg_val_loss


def get_metrics(test,y_test,model):
    loss_fn = nn.MSELoss()

    model.eval()

    y_pred = model(test)
    mse = loss_fn(y_pred, y_test)
    mse = float(mse)
    rmse= np.sqrt(mse)

    test_result= evaluate_soil_property(model,test)
    test_result["obs"] = y_test
    pcip = calculate_pcip(test_result["obs"], test_result['lower'], test_result['upper'])
    r2score = R2Score()
    r2= r2score(y_pred, y_test).item()

    r2_pent =r2*100
    #Balancing Trade-offs between r2 and pcip:
    score_avg = (pcip +  r2_pent)/2
    print(f'MSE: {mse:.4f},R2: {r2:.4f},RMSE: {rmse:.4f}, PCIP: {pcip:.2f},score_avg:{score_avg:.4f}')
    return [mse,r2,rmse,pcip]

def calculate_pcip(y_true, lower_bounds, upper_bounds):
    num_samples = len(y_true)
    num_covering_intervals = np.sum((lower_bounds <= y_true) & (y_true <= upper_bounds))
    pcip = (num_covering_intervals / num_samples) * 100
    return pcip
# Out:
# Using cpu device

# %% [markdown]
# ## 2. Hyperparamter tuning to find best Architecture

# %%
from ray.tune.search.optuna import OptunaSearch
import torch
import torch.optim as optim
import ray
from ray.air import session, Checkpoint
from ray.tune.schedulers import PopulationBasedTraining, HyperBandForBOHB
from ray.tune.schedulers import AsyncHyperBandScheduler
from enum import Enum
loss_fn = nn.MSELoss()


class Optimiser(str, Enum):
    Adams = "Adams"
    SGD ="SGD"
    Adadelta = "Adadelta"
    Adagrad = "Adagrad"
    Adamax = "Adamax"
    Nadam = "Nadam"
    Ftrl = "Ftrl"
    RMSprop="RMSprop"
    LBFGS ="LBFGS"
    #LBFGS ="LBFGS"
    def __str__(self):
        return self.value

 # set your desired L1 regularization strength
def objective(config):  # ①

    #dataset
    train = torch.utils.data.TensorDataset(X_train,y_train)

    val= torch.utils.data.TensorDataset(X_val,y_val)


    #dim = random.sample(output_dims, config["n_layers"])

    criterion=nn.MSELoss()

    #  dimensions to select
    dims = config["dims"]  # You can change this to any number you want



    model = BayesianCNN(num_feature=X_train.shape[1],dims=dims,
                           weight_std=config["weight_std"],
                          bias_std=config["bias_std"],
                        bias_mean=config["bias_mean"],weight_mean=config["weight_mean"]).to("cpu")   # Create a PyTorch conv net

    if config["optimiser"] == Optimiser.RMSprop:
        optimizer = torch.optim.RMSprop(model.parameters(), momentum=config["opt_momentum"], lr=config["lr"])
    elif config["optimiser"] == Optimiser.LBFGS:
        optimizer = torch.optim.LBFGS(model.parameters(),  lr=config["lr"])
    elif config["optimiser"] == Optimiser.Adams:
        optimizer = torch.optim.Adam(model.parameters(),  lr=config["lr"])
    elif config["optimiser"] == Optimiser.SGD:
        optimizer = torch.optim.SGD(model.parameters(),  lr=config["lr"],momentum=config["opt_momentum"])
    elif config["optimiser"] == Optimiser.Nadam:
        optimizer = torch.optim.NAdam(model.parameters(),  lr=config["lr"],momentum_decay=config["opt_momentum"])

    checkpoint = session.get_checkpoint()

    if checkpoint:
        checkpoint_state = checkpoint.to_dict()
        with checkpoint.as_directory() as dir_path:
            print("test")
            model_state, optimizer_state = torch.load(os.path.join(dir_path, "checkpoint.pt"))

            # Load optimizer state (needed since we're using momentum),
            # then set the `lr` and `momentum` according to the config.
            optimizer.load_state_dict(optimizer_state)
            model.load_state_dict(model_state)
        for param_group in optimizer.param_groups:
            if "lr" in config:
                param_group["lr"] = config["lr"]
            if "opt_momentum" in config:
                param_group["opt_momentum"] = config["opt_momentum"]

    while True:

        train_epoch(train,val,model, criterion ,optimizer,config["batch_size"],config["epochs"])  # Train the model

        os.makedirs("model", exist_ok=True)
        torch.save(
            (model.state_dict(), optimizer.state_dict()), "model/checkpoint.pt")

        mse,r2,rmse,pcip = get_metrics(X_test,y_test,model)  # Compute test accuracy
        #optimise with pcip and r2
        r2_pent =r2*100
        score_avg = (pcip+r2_pent)/2
        checkpoint = Checkpoint.from_directory("model")

        session.report({"done": pcip > 99 and rmse < 0.25,"mse": mse, "r2": r2,"rmse": rmse, "pcip": pcip,"score_avg":score_avg},checkpoint=checkpoint)  # Report to Tune

##### RUN  ##############
import ray
from ray.tune.search.hyperopt import HyperOptSearch
from ray.tune.search import ConcurrencyLimiter
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.schedulers.pb2 import PB2
from ray.tune import tune
import random

ray.shutdown()


# Your original list of dimensions
original_dims = [1024,512, 256,  128, 64, 32,  16,  8, 512,256,128,64,28,8]
# List of optimizer names
optimizer_names = ["Adams", "SGD","Nadam"]
optimizer_names = ["Adams", "Nadam"]
ray.init(num_cpus=12, num_gpus=0,_temp_dir="/ray") # assign the total # of cpus and gpus, make sure you have ray.init in the beginning and ray.shutdown at the end
sched = AsyncHyperBandScheduler(  time_attr="training_iteration",
    reduction_factor=2,
    metric='rmse',
    mode='min')  # set a scheduler

perturbation_interval = 10
#use population based training
scheduler =PopulationBasedTraining(
       time_attr="training_iteration",
    perturbation_interval=perturbation_interval,
    metric="rmse",
    mode="min",
    quantile_fraction=0.25,  # copy bottom % with top %
    #hyperparam_mutation - for pbt
    hyperparam_mutations={
        # distribution for resampling
        "lr": [0.0001, 0.1],
        "momentum": [0.009,0.01],
        "opt_momentum": [0.009,0.01],
    }
)
algo =OptunaSearch(metric=["rmse","pcip"], mode=["min","max"])# HyperOptSearch() # if you want to use the Bayesian optimization, import BayesOptSearch instead
algo = ConcurrencyLimiter(algo, max_concurrent=10)
scheduler = HyperBandForBOHB(
    time_attr="training_iteration",
    max_t=20,
    metric="score_avg",
    mode='max',
    reduction_factor=0.25,
    stop_last_trials=False,
)
scheduler = PB2(
    time_attr="training_iteration",
    perturbation_interval=perturbation_interval,
    metric="score_avg",
    mode="max",
    quantile_fraction=0.2,  # copy bottom % with top %
    #hyperparam_mutation - for pbt
    hyperparam_bounds={
        # distribution for resampling
        "lr": [0.00001, 0.1],
        "momentum": [0.009,0.01],
        "opt_momentum": [0.009,0.01],
    },
)
analysis = tune.run(
        objective,   # the core training/testing of your model
        #storage_path=os.getcwd(), # for saving the log files
        name="pbt2_silt_2", # name for the result directory
        #resume="REMOTE",
        #metric="rmse",
        #resume="PROMPT",
        #mode='min',
        #search_alg=algo,
        scheduler=scheduler,
        stop={
                "training_iteration": 20,
                "done": True,
                "rmse": 0.05,
        },
        resources_per_trial={
                "cpu": 1,
                "gpu": 0
         },
        num_samples=30, # 50 trials
        progress_reporter=ray.tune.JupyterNotebookReporter(metric="score_avg",overwrite=True,max_report_frequency=7),
        config={

               "lr": ray.tune.loguniform(0.00001, 0.1),
                  #"pred_interval_constant":ray.tune.loguniform(0.28, 12.05),
                 "momentum": ray.tune.loguniform(0.009,0.01),
                "opt_momentum": ray.tune.loguniform(0.009,0.01),
                 "weight_std": ray.tune.loguniform(0.0001,10.02),
                 "weight_mean": ray.tune.loguniform(0.0001,10.02),
                 "bias_mean": ray.tune.loguniform(0.0001,10.02),
                 "bias_std": ray.tune.loguniform(0.01, 17.7),
                 "batch_size": ray.tune.randint(2,128),
                 "epochs":ray.tune.randint(2,1000),
                 "dims": ray.tune.sample_from(lambda spec: random.choices(original_dims,k=random.randint(2, 7))),
                 "optimiser": ray.tune.sample_from(lambda spec: random.choice(optimizer_names)),
                 "checkpoint_interval": perturbation_interval
        })
# Out:
# 2023-11-24 12:15:09,934	INFO tune.py:657 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# 2023-11-24 12:15:10,032	WARNING callback.py:144 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# 2023-11-24 12:15:11,977	WARNING worker.py:2037 -- Warning: The actor ImplicitFunc is very large (10 MiB). Check that its definition is not implicitly capturing a large array or other object in scope. Tip: use ray.put() to put large objects in the Ray object store.
# (pid=7680) C:\Users\omondiagbep\Anaconda3\envs\pytorch\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# (pid=7680) C:\Users\omondiagbep\Anaconda3\envs\pytorch\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# (pid=7680) C:\Users\omondiagbep\Anaconda3\envs\pytorch\lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-gcc_10_3_0.dll
# (pid=7680)   warnings.warn("loaded more than 1 DLL from .libs:"
# (pid=7680) C:\Users\omondiagbep\Anaconda3\envs\pytorch\lib\site-packages\torchaudio\backend\utils.py:74: UserWarning: No audio backend is available.
# (pid=7680)   warnings.warn("No audio backend is available.")
# (pid=30456) C:\Users\omondiagbep\Anaconda3\envs\pytorch\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs: [repeated 11x across cluster]
# (pid=30456) C:\Users\omondiagbep\Anaconda3\envs\pytorch\lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-gcc_10_3_0.dll [repeated 22x across cluster]
# (pid=30456)   warnings.warn("loaded more than 1 DLL from .libs:" [repeated 11x across cluster]
# (objective pid=39492) C:\Users\omondiagbep\AppData\Local\Temp\ipykernel_48000\1125594858.py:46: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:248.)
# (pid=30456) C:\Users\omondiagbep\Anaconda3\envs\pytorch\lib\site-packages\torchaudio\backend\utils.py:74: UserWarning: No audio backend is available. [repeated 11x across cluster]
# (pid=30456)   warnings.warn("No audio backend is available.") [repeated 11x across cluster]
# (objective pid=39492) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00008_8_batch_size=73,bias_mean=0.0017,bias_std=2.4035,epochs=27,lr=0.0410,momentum=0.0095,opt_momentum=0.0093,wei_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to 'c:///Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00008_8_batch_size=73,bias_mean=0.0017,bias_std=2.4035,epochs=27,lr=0.0410,momentum=0.0095,opt_momentum=0.0093,wei_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=39492) . Retrying after sleeping for 1.0 seconds...
# (objective pid=39492) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00008_8_batch_size=73,bias_mean=0.0017,bias_std=2.4035,epochs=27,lr=0.0410,momentum=0.0095,opt_momentum=0.0093,wei_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00008_8_batch_size=73,bias_mean=0.0017,bias_std=2.4035,epochs=27,lr=0.0410,momentum=0.0095,opt_momentum=0.0093,wei_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=39492) . Retrying after sleeping for 1.0 seconds...
# (objective pid=39492) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00008_8_batch_size=73,bias_mean=0.0017,bias_std=2.4035,epochs=27,lr=0.0410,momentum=0.0095,opt_momentum=0.0093,wei_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00008_8_batch_size=73,bias_mean=0.0017,bias_std=2.4035,epochs=27,lr=0.0410,momentum=0.0095,opt_momentum=0.0093,wei_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=39492) . Retrying after sleeping for 1.0 seconds...
# (objective pid=39492) Could not upload checkpoint to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00008_8_batch_size=73,bias_mean=0.0017,bias_std=2.4035,epochs=27,lr=0.0410,momentum=0.0095,opt_momentum=0.0093,wei_2023-11-24_12-15-11\checkpoint_000000 even after 3 retries.Please check if the credentials expired and that the remote filesystem is supported. For large checkpoints or artifacts, consider increasing `SyncConfig(sync_timeout)` (current value: 1800 seconds).
# (objective pid=39492) Last sync still in progress, skipping sync up of C:\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00008_8_batch_size=73,bias_mean=0.0017,bias_std=2.4035,epochs=27,lr=0.0410,momentum=0.0095,opt_momentum=0.0093,wei_2023-11-24_12-15-11\ to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00008_8_batch_size=73,bias_mean=0.0017,bias_std=2.4035,epochs=27,lr=0.0410,momentum=0.0095,opt_momentum=0.0093,wei_2023-11-24_12-15-11
# (objective pid=39492) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00008_8_batch_size=73,bias_mean=0.0017,bias_std=2.4035,epochs=27,lr=0.0410,momentum=0.0095,opt_momentum=0.0093,wei_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00008_8_batch_size=73,bias_mean=0.0017,bias_std=2.4035,epochs=27,lr=0.0410,momentum=0.0095,opt_momentum=0.0093,wei_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=39492) . Retrying after sleeping for 1.0 seconds...
# (objective pid=39492) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00008_8_batch_size=73,bias_mean=0.0017,bias_std=2.4035,epochs=27,lr=0.0410,momentum=0.0095,opt_momentum=0.0093,wei_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00008_8_batch_size=73,bias_mean=0.0017,bias_std=2.4035,epochs=27,lr=0.0410,momentum=0.0095,opt_momentum=0.0093,wei_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=39492) . Retrying after sleeping for 1.0 seconds...
# (objective pid=39492) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00008_8_batch_size=73,bias_mean=0.0017,bias_std=2.4035,epochs=27,lr=0.0410,momentum=0.0095,opt_momentum=0.0093,wei_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00008_8_batch_size=73,bias_mean=0.0017,bias_std=2.4035,epochs=27,lr=0.0410,momentum=0.0095,opt_momentum=0.0093,wei_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=39492) . Retrying after sleeping for 1.0 seconds...
# (objective pid=39492) Could not upload checkpoint to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00008_8_batch_size=73,bias_mean=0.0017,bias_std=2.4035,epochs=27,lr=0.0410,momentum=0.0095,opt_momentum=0.0093,wei_2023-11-24_12-15-11 even after 3 retries.Please check if the credentials expired and that the remote filesystem is supported. For large checkpoints or artifacts, consider increasing `SyncConfig(sync_timeout)` (current value: 1800 seconds).
# (objective pid=1868) C:\Users\omondiagbep\AppData\Local\Temp\ipykernel_48000\1125594858.py:46: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:248.)
# (objective pid=1868) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00011_11_batch_size=42,bias_mean=0.0238,bias_std=0.3830,epochs=78,lr=0.0001,momentum=0.0098,opt_momentum=0.0095,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to 'c:///Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00011_11_batch_size=42,bias_mean=0.0238,bias_std=0.3830,epochs=78,lr=0.0001,momentum=0.0098,opt_momentum=0.0095,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=1868) . Retrying after sleeping for 1.0 seconds...
# (objective pid=1868) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00011_11_batch_size=42,bias_mean=0.0238,bias_std=0.3830,epochs=78,lr=0.0001,momentum=0.0098,opt_momentum=0.0095,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00011_11_batch_size=42,bias_mean=0.0238,bias_std=0.3830,epochs=78,lr=0.0001,momentum=0.0098,opt_momentum=0.0095,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=1868) . Retrying after sleeping for 1.0 seconds...
# (objective pid=1868) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00011_11_batch_size=42,bias_mean=0.0238,bias_std=0.3830,epochs=78,lr=0.0001,momentum=0.0098,opt_momentum=0.0095,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00011_11_batch_size=42,bias_mean=0.0238,bias_std=0.3830,epochs=78,lr=0.0001,momentum=0.0098,opt_momentum=0.0095,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=1868) . Retrying after sleeping for 1.0 seconds...
# (objective pid=1868) Could not upload checkpoint to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00011_11_batch_size=42,bias_mean=0.0238,bias_std=0.3830,epochs=78,lr=0.0001,momentum=0.0098,opt_momentum=0.0095,we_2023-11-24_12-15-11\checkpoint_000000 even after 3 retries.Please check if the credentials expired and that the remote filesystem is supported. For large checkpoints or artifacts, consider increasing `SyncConfig(sync_timeout)` (current value: 1800 seconds).
# (objective pid=1868) Last sync still in progress, skipping sync up of C:\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00011_11_batch_size=42,bias_mean=0.0238,bias_std=0.3830,epochs=78,lr=0.0001,momentum=0.0098,opt_momentum=0.0095,we_2023-11-24_12-15-11\ to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00011_11_batch_size=42,bias_mean=0.0238,bias_std=0.3830,epochs=78,lr=0.0001,momentum=0.0098,opt_momentum=0.0095,we_2023-11-24_12-15-11
# (objective pid=1868) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00011_11_batch_size=42,bias_mean=0.0238,bias_std=0.3830,epochs=78,lr=0.0001,momentum=0.0098,opt_momentum=0.0095,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00011_11_batch_size=42,bias_mean=0.0238,bias_std=0.3830,epochs=78,lr=0.0001,momentum=0.0098,opt_momentum=0.0095,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=1868) . Retrying after sleeping for 1.0 seconds...
# (objective pid=1868) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00011_11_batch_size=42,bias_mean=0.0238,bias_std=0.3830,epochs=78,lr=0.0001,momentum=0.0098,opt_momentum=0.0095,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00011_11_batch_size=42,bias_mean=0.0238,bias_std=0.3830,epochs=78,lr=0.0001,momentum=0.0098,opt_momentum=0.0095,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=1868) . Retrying after sleeping for 1.0 seconds...
# (objective pid=1868) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00011_11_batch_size=42,bias_mean=0.0238,bias_std=0.3830,epochs=78,lr=0.0001,momentum=0.0098,opt_momentum=0.0095,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00011_11_batch_size=42,bias_mean=0.0238,bias_std=0.3830,epochs=78,lr=0.0001,momentum=0.0098,opt_momentum=0.0095,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=1868) . Retrying after sleeping for 1.0 seconds...
# (objective pid=1868) Could not upload checkpoint to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00011_11_batch_size=42,bias_mean=0.0238,bias_std=0.3830,epochs=78,lr=0.0001,momentum=0.0098,opt_momentum=0.0095,we_2023-11-24_12-15-11 even after 3 retries.Please check if the credentials expired and that the remote filesystem is supported. For large checkpoints or artifacts, consider increasing `SyncConfig(sync_timeout)` (current value: 1800 seconds).
# (objective pid=39492) Last sync command failed: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00008_8_batch_size=73,bias_mean=0.0017,bias_std=2.4035,epochs=27,lr=0.0410,momentum=0.0095,opt_momentum=0.0093,wei_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00008_8_batch_size=73,bias_mean=0.0017,bias_std=2.4035,epochs=27,lr=0.0410,momentum=0.0095,opt_momentum=0.0093,wei_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=39492)
# (objective pid=39492) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00012_12_batch_size=120,bias_mean=9.0990,bias_std=0.1286,epochs=336,lr=0.0000,momentum=0.0097,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to 'c:///Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00012_12_batch_size=120,bias_mean=9.0990,bias_std=0.1286,epochs=336,lr=0.0000,momentum=0.0097,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=39492) . Retrying after sleeping for 1.0 seconds...
# (objective pid=39492) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00012_12_batch_size=120,bias_mean=9.0990,bias_std=0.1286,epochs=336,lr=0.0000,momentum=0.0097,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00012_12_batch_size=120,bias_mean=9.0990,bias_std=0.1286,epochs=336,lr=0.0000,momentum=0.0097,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=39492) . Retrying after sleeping for 1.0 seconds...
# (objective pid=39492) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00012_12_batch_size=120,bias_mean=9.0990,bias_std=0.1286,epochs=336,lr=0.0000,momentum=0.0097,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00012_12_batch_size=120,bias_mean=9.0990,bias_std=0.1286,epochs=336,lr=0.0000,momentum=0.0097,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=39492) . Retrying after sleeping for 1.0 seconds...
# (objective pid=39492) Could not upload checkpoint to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00012_12_batch_size=120,bias_mean=9.0990,bias_std=0.1286,epochs=336,lr=0.0000,momentum=0.0097,opt_momentum=0.0095,_2023-11-24_12-15-11\checkpoint_000000 even after 3 retries.Please check if the credentials expired and that the remote filesystem is supported. For large checkpoints or artifacts, consider increasing `SyncConfig(sync_timeout)` (current value: 1800 seconds).
# (objective pid=39492) Last sync still in progress, skipping sync up of C:\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00012_12_batch_size=120,bias_mean=9.0990,bias_std=0.1286,epochs=336,lr=0.0000,momentum=0.0097,opt_momentum=0.0095,_2023-11-24_12-15-11\ to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00012_12_batch_size=120,bias_mean=9.0990,bias_std=0.1286,epochs=336,lr=0.0000,momentum=0.0097,opt_momentum=0.0095,_2023-11-24_12-15-11
# (objective pid=39492) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00012_12_batch_size=120,bias_mean=9.0990,bias_std=0.1286,epochs=336,lr=0.0000,momentum=0.0097,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00012_12_batch_size=120,bias_mean=9.0990,bias_std=0.1286,epochs=336,lr=0.0000,momentum=0.0097,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=39492) . Retrying after sleeping for 1.0 seconds...
# (objective pid=39492) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00012_12_batch_size=120,bias_mean=9.0990,bias_std=0.1286,epochs=336,lr=0.0000,momentum=0.0097,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00012_12_batch_size=120,bias_mean=9.0990,bias_std=0.1286,epochs=336,lr=0.0000,momentum=0.0097,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=39492) . Retrying after sleeping for 1.0 seconds...
# (objective pid=39492) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00012_12_batch_size=120,bias_mean=9.0990,bias_std=0.1286,epochs=336,lr=0.0000,momentum=0.0097,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00012_12_batch_size=120,bias_mean=9.0990,bias_std=0.1286,epochs=336,lr=0.0000,momentum=0.0097,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=39492) . Retrying after sleeping for 1.0 seconds...
# (objective pid=39492) Could not upload checkpoint to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00012_12_batch_size=120,bias_mean=9.0990,bias_std=0.1286,epochs=336,lr=0.0000,momentum=0.0097,opt_momentum=0.0095,_2023-11-24_12-15-11 even after 3 retries.Please check if the credentials expired and that the remote filesystem is supported. For large checkpoints or artifacts, consider increasing `SyncConfig(sync_timeout)` (current value: 1800 seconds).
# (objective pid=5952) C:\Users\omondiagbep\AppData\Local\Temp\ipykernel_48000\1125594858.py:46: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:248.)
# (objective pid=5952) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00006_6_batch_size=119,bias_mean=2.8056,bias_std=10.3374,epochs=781,lr=0.0051,momentum=0.0093,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to 'c:///Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00006_6_batch_size=119,bias_mean=2.8056,bias_std=10.3374,epochs=781,lr=0.0051,momentum=0.0093,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=5952) . Retrying after sleeping for 1.0 seconds...
# (objective pid=5952) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00006_6_batch_size=119,bias_mean=2.8056,bias_std=10.3374,epochs=781,lr=0.0051,momentum=0.0093,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00006_6_batch_size=119,bias_mean=2.8056,bias_std=10.3374,epochs=781,lr=0.0051,momentum=0.0093,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=5952) . Retrying after sleeping for 1.0 seconds...
# (objective pid=5952) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00006_6_batch_size=119,bias_mean=2.8056,bias_std=10.3374,epochs=781,lr=0.0051,momentum=0.0093,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00006_6_batch_size=119,bias_mean=2.8056,bias_std=10.3374,epochs=781,lr=0.0051,momentum=0.0093,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=5952) . Retrying after sleeping for 1.0 seconds...
# (objective pid=5952) Could not upload checkpoint to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00006_6_batch_size=119,bias_mean=2.8056,bias_std=10.3374,epochs=781,lr=0.0051,momentum=0.0093,opt_momentum=0.0095,_2023-11-24_12-15-11\checkpoint_000000 even after 3 retries.Please check if the credentials expired and that the remote filesystem is supported. For large checkpoints or artifacts, consider increasing `SyncConfig(sync_timeout)` (current value: 1800 seconds).
# (objective pid=5952) Last sync still in progress, skipping sync up of C:\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00006_6_batch_size=119,bias_mean=2.8056,bias_std=10.3374,epochs=781,lr=0.0051,momentum=0.0093,opt_momentum=0.0095,_2023-11-24_12-15-11\ to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00006_6_batch_size=119,bias_mean=2.8056,bias_std=10.3374,epochs=781,lr=0.0051,momentum=0.0093,opt_momentum=0.0095,_2023-11-24_12-15-11
# (objective pid=5952) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00006_6_batch_size=119,bias_mean=2.8056,bias_std=10.3374,epochs=781,lr=0.0051,momentum=0.0093,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00006_6_batch_size=119,bias_mean=2.8056,bias_std=10.3374,epochs=781,lr=0.0051,momentum=0.0093,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=5952) . Retrying after sleeping for 1.0 seconds...
# (objective pid=5952) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00006_6_batch_size=119,bias_mean=2.8056,bias_std=10.3374,epochs=781,lr=0.0051,momentum=0.0093,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00006_6_batch_size=119,bias_mean=2.8056,bias_std=10.3374,epochs=781,lr=0.0051,momentum=0.0093,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=5952) . Retrying after sleeping for 1.0 seconds...
# (objective pid=5952) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00006_6_batch_size=119,bias_mean=2.8056,bias_std=10.3374,epochs=781,lr=0.0051,momentum=0.0093,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00006_6_batch_size=119,bias_mean=2.8056,bias_std=10.3374,epochs=781,lr=0.0051,momentum=0.0093,opt_momentum=0.0095,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=5952) . Retrying after sleeping for 1.0 seconds...
# (objective pid=5952) Could not upload checkpoint to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00006_6_batch_size=119,bias_mean=2.8056,bias_std=10.3374,epochs=781,lr=0.0051,momentum=0.0093,opt_momentum=0.0095,_2023-11-24_12-15-11 even after 3 retries.Please check if the credentials expired and that the remote filesystem is supported. For large checkpoints or artifacts, consider increasing `SyncConfig(sync_timeout)` (current value: 1800 seconds).
# (objective pid=25808) C:\Users\omondiagbep\AppData\Local\Temp\ipykernel_48000\1125594858.py:46: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:248.)
# (objective pid=25808) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00010_10_batch_size=109,bias_mean=0.0053,bias_std=0.0254,epochs=343,lr=0.0000,momentum=0.0092,opt_momentum=0.0091,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to 'c:///Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00010_10_batch_size=109,bias_mean=0.0053,bias_std=0.0254,epochs=343,lr=0.0000,momentum=0.0092,opt_momentum=0.0091,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=25808) . Retrying after sleeping for 1.0 seconds...
# (objective pid=25808) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00010_10_batch_size=109,bias_mean=0.0053,bias_std=0.0254,epochs=343,lr=0.0000,momentum=0.0092,opt_momentum=0.0091,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00010_10_batch_size=109,bias_mean=0.0053,bias_std=0.0254,epochs=343,lr=0.0000,momentum=0.0092,opt_momentum=0.0091,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=25808) . Retrying after sleeping for 1.0 seconds...
# (objective pid=25808) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00010_10_batch_size=109,bias_mean=0.0053,bias_std=0.0254,epochs=343,lr=0.0000,momentum=0.0092,opt_momentum=0.0091,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00010_10_batch_size=109,bias_mean=0.0053,bias_std=0.0254,epochs=343,lr=0.0000,momentum=0.0092,opt_momentum=0.0091,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=25808) . Retrying after sleeping for 1.0 seconds...
# (objective pid=25808) Could not upload checkpoint to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00010_10_batch_size=109,bias_mean=0.0053,bias_std=0.0254,epochs=343,lr=0.0000,momentum=0.0092,opt_momentum=0.0091,_2023-11-24_12-15-11\checkpoint_000000 even after 3 retries.Please check if the credentials expired and that the remote filesystem is supported. For large checkpoints or artifacts, consider increasing `SyncConfig(sync_timeout)` (current value: 1800 seconds).
# (objective pid=25808) Last sync still in progress, skipping sync up of C:\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00010_10_batch_size=109,bias_mean=0.0053,bias_std=0.0254,epochs=343,lr=0.0000,momentum=0.0092,opt_momentum=0.0091,_2023-11-24_12-15-11\ to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00010_10_batch_size=109,bias_mean=0.0053,bias_std=0.0254,epochs=343,lr=0.0000,momentum=0.0092,opt_momentum=0.0091,_2023-11-24_12-15-11
# (objective pid=25808) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00010_10_batch_size=109,bias_mean=0.0053,bias_std=0.0254,epochs=343,lr=0.0000,momentum=0.0092,opt_momentum=0.0091,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00010_10_batch_size=109,bias_mean=0.0053,bias_std=0.0254,epochs=343,lr=0.0000,momentum=0.0092,opt_momentum=0.0091,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=25808) . Retrying after sleeping for 1.0 seconds...
# (objective pid=25808) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00010_10_batch_size=109,bias_mean=0.0053,bias_std=0.0254,epochs=343,lr=0.0000,momentum=0.0092,opt_momentum=0.0091,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00010_10_batch_size=109,bias_mean=0.0053,bias_std=0.0254,epochs=343,lr=0.0000,momentum=0.0092,opt_momentum=0.0091,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=25808) . Retrying after sleeping for 1.0 seconds...
# (objective pid=25808) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00010_10_batch_size=109,bias_mean=0.0053,bias_std=0.0254,epochs=343,lr=0.0000,momentum=0.0092,opt_momentum=0.0091,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00010_10_batch_size=109,bias_mean=0.0053,bias_std=0.0254,epochs=343,lr=0.0000,momentum=0.0092,opt_momentum=0.0091,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=25808) . Retrying after sleeping for 1.0 seconds...
# (objective pid=25808) Could not upload checkpoint to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00010_10_batch_size=109,bias_mean=0.0053,bias_std=0.0254,epochs=343,lr=0.0000,momentum=0.0092,opt_momentum=0.0091,_2023-11-24_12-15-11 even after 3 retries.Please check if the credentials expired and that the remote filesystem is supported. For large checkpoints or artifacts, consider increasing `SyncConfig(sync_timeout)` (current value: 1800 seconds).
# (objective pid=25808) Last sync command failed: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00010_10_batch_size=109,bias_mean=0.0053,bias_std=0.0254,epochs=343,lr=0.0000,momentum=0.0092,opt_momentum=0.0091,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00010_10_batch_size=109,bias_mean=0.0053,bias_std=0.0254,epochs=343,lr=0.0000,momentum=0.0092,opt_momentum=0.0091,_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=25808)
# (objective pid=25808) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00016_16_batch_size=82,bias_mean=0.1074,bias_std=15.9886,epochs=45,lr=0.0000,momentum=0.0091,opt_momentum=0.0098,w_2023-11-24_12-15-23/checkpoint_000000/.is_checkpoint' to 'c:///Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00016_16_batch_size=82,bias_mean=0.1074,bias_std=15.9886,epochs=45,lr=0.0000,momentum=0.0091,opt_momentum=0.0098,w_2023-11-24_12-15-23/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=25808) . Retrying after sleeping for 1.0 seconds...
# (objective pid=25808) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00016_16_batch_size=82,bias_mean=0.1074,bias_std=15.9886,epochs=45,lr=0.0000,momentum=0.0091,opt_momentum=0.0098,w_2023-11-24_12-15-23/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00016_16_batch_size=82,bias_mean=0.1074,bias_std=15.9886,epochs=45,lr=0.0000,momentum=0.0091,opt_momentum=0.0098,w_2023-11-24_12-15-23/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=25808) . Retrying after sleeping for 1.0 seconds...
# (objective pid=25808) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00016_16_batch_size=82,bias_mean=0.1074,bias_std=15.9886,epochs=45,lr=0.0000,momentum=0.0091,opt_momentum=0.0098,w_2023-11-24_12-15-23/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00016_16_batch_size=82,bias_mean=0.1074,bias_std=15.9886,epochs=45,lr=0.0000,momentum=0.0091,opt_momentum=0.0098,w_2023-11-24_12-15-23/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=25808) . Retrying after sleeping for 1.0 seconds...
# (objective pid=25808) Could not upload checkpoint to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00016_16_batch_size=82,bias_mean=0.1074,bias_std=15.9886,epochs=45,lr=0.0000,momentum=0.0091,opt_momentum=0.0098,w_2023-11-24_12-15-23\checkpoint_000000 even after 3 retries.Please check if the credentials expired and that the remote filesystem is supported. For large checkpoints or artifacts, consider increasing `SyncConfig(sync_timeout)` (current value: 1800 seconds).
# (objective pid=25808) Last sync still in progress, skipping sync up of C:\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00016_16_batch_size=82,bias_mean=0.1074,bias_std=15.9886,epochs=45,lr=0.0000,momentum=0.0091,opt_momentum=0.0098,w_2023-11-24_12-15-23\ to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00016_16_batch_size=82,bias_mean=0.1074,bias_std=15.9886,epochs=45,lr=0.0000,momentum=0.0091,opt_momentum=0.0098,w_2023-11-24_12-15-23
# (objective pid=25808) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00016_16_batch_size=82,bias_mean=0.1074,bias_std=15.9886,epochs=45,lr=0.0000,momentum=0.0091,opt_momentum=0.0098,w_2023-11-24_12-15-23/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00016_16_batch_size=82,bias_mean=0.1074,bias_std=15.9886,epochs=45,lr=0.0000,momentum=0.0091,opt_momentum=0.0098,w_2023-11-24_12-15-23/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=25808) . Retrying after sleeping for 1.0 seconds...
# (objective pid=25808) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00016_16_batch_size=82,bias_mean=0.1074,bias_std=15.9886,epochs=45,lr=0.0000,momentum=0.0091,opt_momentum=0.0098,w_2023-11-24_12-15-23/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00016_16_batch_size=82,bias_mean=0.1074,bias_std=15.9886,epochs=45,lr=0.0000,momentum=0.0091,opt_momentum=0.0098,w_2023-11-24_12-15-23/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=25808) . Retrying after sleeping for 1.0 seconds...
# (objective pid=25808) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00016_16_batch_size=82,bias_mean=0.1074,bias_std=15.9886,epochs=45,lr=0.0000,momentum=0.0091,opt_momentum=0.0098,w_2023-11-24_12-15-23/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00016_16_batch_size=82,bias_mean=0.1074,bias_std=15.9886,epochs=45,lr=0.0000,momentum=0.0091,opt_momentum=0.0098,w_2023-11-24_12-15-23/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=25808) . Retrying after sleeping for 1.0 seconds...
# (objective pid=25808) Could not upload checkpoint to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00016_16_batch_size=82,bias_mean=0.1074,bias_std=15.9886,epochs=45,lr=0.0000,momentum=0.0091,opt_momentum=0.0098,w_2023-11-24_12-15-23 even after 3 retries.Please check if the credentials expired and that the remote filesystem is supported. For large checkpoints or artifacts, consider increasing `SyncConfig(sync_timeout)` (current value: 1800 seconds).
# (objective pid=43944) C:\Users\omondiagbep\AppData\Local\Temp\ipykernel_48000\1125594858.py:46: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:248.)
# (objective pid=43944) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00005_5_batch_size=65,bias_mean=0.0028,bias_std=0.0583,epochs=892,lr=0.0014,momentum=0.0098,opt_momentum=0.0097,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to 'c:///Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00005_5_batch_size=65,bias_mean=0.0028,bias_std=0.0583,epochs=892,lr=0.0014,momentum=0.0098,opt_momentum=0.0097,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=43944) . Retrying after sleeping for 1.0 seconds...
# (objective pid=43944) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00005_5_batch_size=65,bias_mean=0.0028,bias_std=0.0583,epochs=892,lr=0.0014,momentum=0.0098,opt_momentum=0.0097,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00005_5_batch_size=65,bias_mean=0.0028,bias_std=0.0583,epochs=892,lr=0.0014,momentum=0.0098,opt_momentum=0.0097,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=43944) . Retrying after sleeping for 1.0 seconds...
# (objective pid=43944) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00005_5_batch_size=65,bias_mean=0.0028,bias_std=0.0583,epochs=892,lr=0.0014,momentum=0.0098,opt_momentum=0.0097,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00005_5_batch_size=65,bias_mean=0.0028,bias_std=0.0583,epochs=892,lr=0.0014,momentum=0.0098,opt_momentum=0.0097,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=43944) . Retrying after sleeping for 1.0 seconds...
# (objective pid=43944) Could not upload checkpoint to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00005_5_batch_size=65,bias_mean=0.0028,bias_std=0.0583,epochs=892,lr=0.0014,momentum=0.0098,opt_momentum=0.0097,we_2023-11-24_12-15-11\checkpoint_000000 even after 3 retries.Please check if the credentials expired and that the remote filesystem is supported. For large checkpoints or artifacts, consider increasing `SyncConfig(sync_timeout)` (current value: 1800 seconds).
# (objective pid=43944) Last sync still in progress, skipping sync up of C:\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00005_5_batch_size=65,bias_mean=0.0028,bias_std=0.0583,epochs=892,lr=0.0014,momentum=0.0098,opt_momentum=0.0097,we_2023-11-24_12-15-11\ to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00005_5_batch_size=65,bias_mean=0.0028,bias_std=0.0583,epochs=892,lr=0.0014,momentum=0.0098,opt_momentum=0.0097,we_2023-11-24_12-15-11
# (objective pid=43944) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00005_5_batch_size=65,bias_mean=0.0028,bias_std=0.0583,epochs=892,lr=0.0014,momentum=0.0098,opt_momentum=0.0097,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00005_5_batch_size=65,bias_mean=0.0028,bias_std=0.0583,epochs=892,lr=0.0014,momentum=0.0098,opt_momentum=0.0097,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=43944) . Retrying after sleeping for 1.0 seconds...
# (objective pid=43944) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00005_5_batch_size=65,bias_mean=0.0028,bias_std=0.0583,epochs=892,lr=0.0014,momentum=0.0098,opt_momentum=0.0097,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00005_5_batch_size=65,bias_mean=0.0028,bias_std=0.0583,epochs=892,lr=0.0014,momentum=0.0098,opt_momentum=0.0097,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=43944) . Retrying after sleeping for 1.0 seconds...
# (objective pid=43944) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00005_5_batch_size=65,bias_mean=0.0028,bias_std=0.0583,epochs=892,lr=0.0014,momentum=0.0098,opt_momentum=0.0097,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to '/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00005_5_batch_size=65,bias_mean=0.0028,bias_std=0.0583,epochs=892,lr=0.0014,momentum=0.0098,opt_momentum=0.0097,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=43944) . Retrying after sleeping for 1.0 seconds...
# (objective pid=43944) Could not upload checkpoint to c://\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00005_5_batch_size=65,bias_mean=0.0028,bias_std=0.0583,epochs=892,lr=0.0014,momentum=0.0098,opt_momentum=0.0097,we_2023-11-24_12-15-11 even after 3 retries.Please check if the credentials expired and that the remote filesystem is supported. For large checkpoints or artifacts, consider increasing `SyncConfig(sync_timeout)` (current value: 1800 seconds).
# (objective pid=19164) C:\Users\omondiagbep\AppData\Local\Temp\ipykernel_48000\1125594858.py:46: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:248.)
# (objective pid=19164) Caught sync error: Sync process failed: [WinError 32] Failed copying 'C:/Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00003_3_batch_size=52,bias_mean=0.0009,bias_std=0.0355,epochs=355,lr=0.0023,momentum=0.0098,opt_momentum=0.0097,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint' to 'c:///Users/omondiagbep/ray_results/pbt2_silt_2/objective_25c18_00003_3_batch_size=52,bias_mean=0.0009,bias_std=0.0355,epochs=355,lr=0.0023,momentum=0.0098,opt_momentum=0.0097,we_2023-11-24_12-15-11/checkpoint_000000/.is_checkpoint'. Detail: [Windows error 32] The process cannot access the file because it is being used by another process.
# (objective pid=19164) . Retrying after sleeping for 1.0 seconds...
# ...
# (objective pid=7680) Epoch [842/841] Val Loss: 1.14085 [repeated 4x across cluster]
# (objective pid=7680) Epoch [484/841] Loss: 0.21859 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 5.49387 [repeated 4x across cluster]
# (objective pid=7680) Epoch [488/841] Loss: 3.75709 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.91118 [repeated 4x across cluster]
# (objective pid=7680) Epoch [492/841] Loss: 3.06606 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 7.02417 [repeated 4x across cluster]
# (objective pid=7680) Epoch [496/841] Loss: 0.64082 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.41266 [repeated 4x across cluster]
# (objective pid=7680) Epoch [500/841] Loss: 0.62746 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.75473 [repeated 4x across cluster]
# (objective pid=7680) Epoch [504/841] Loss: 1.05558 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 4.68863 [repeated 4x across cluster]
# (objective pid=7680) Epoch [508/841] Loss: 2.48981 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.38387 [repeated 4x across cluster]
# (objective pid=7680) Epoch [512/841] Loss: 0.74034 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.12519 [repeated 4x across cluster]
# (objective pid=7680) Epoch [516/841] Loss: 2.98147 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.84197 [repeated 4x across cluster]
# (objective pid=7680) Epoch [520/841] Loss: 0.32984 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 2.38432 [repeated 4x across cluster]
# (objective pid=7680) Epoch [524/841] Loss: 2.38112 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 4.03991 [repeated 4x across cluster]
# (objective pid=7680) Epoch [528/841] Loss: 2.12966 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.00262 [repeated 4x across cluster]
# (objective pid=7680) Epoch [532/841] Loss: 0.82826 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 2.89497 [repeated 4x across cluster]
# (objective pid=7680) Epoch [536/841] Loss: 2.48758 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.14613 [repeated 4x across cluster]
# (objective pid=7680) Epoch [540/841] Loss: 1.75513 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.02052 [repeated 4x across cluster]
# (objective pid=7680) Epoch [544/841] Loss: 2.85258 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 4.13800 [repeated 4x across cluster]
# (objective pid=7680) Epoch [548/841] Loss: 2.37118 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.00213 [repeated 4x across cluster]
# (objective pid=7680) Epoch [552/841] Loss: 4.51287 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 2.84712 [repeated 4x across cluster]
# (objective pid=7680) Epoch [556/841] Loss: 0.88188 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.45221 [repeated 4x across cluster]
# (objective pid=7680) Epoch [560/841] Loss: 2.46475 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.62002 [repeated 4x across cluster]
# (objective pid=7680) Epoch [564/841] Loss: 0.73364 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.29352 [repeated 4x across cluster]
# (objective pid=7680) Epoch [568/841] Loss: 2.28589 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.56939 [repeated 4x across cluster]
# (objective pid=7680) Epoch [572/841] Loss: 1.15358 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.26868 [repeated 4x across cluster]
# (objective pid=7680) Epoch [576/841] Loss: 2.27763 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.10095 [repeated 4x across cluster]
# (objective pid=7680) Epoch [580/841] Loss: 0.49602 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.91567 [repeated 4x across cluster]
# (objective pid=7680) Epoch [584/841] Loss: 0.42936 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 3.29515 [repeated 4x across cluster]
# (objective pid=7680) Epoch [588/841] Loss: 3.64677 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.90305 [repeated 4x across cluster]
# (objective pid=7680) Epoch [592/841] Loss: 0.44793 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.53197 [repeated 4x across cluster]
# (objective pid=7680) Epoch [596/841] Loss: 3.93467 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.05077 [repeated 4x across cluster]
# (objective pid=7680) Epoch [600/841] Loss: 1.52214 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 2.85431 [repeated 4x across cluster]
# (objective pid=7680) Epoch [604/841] Loss: 0.90697 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.63505 [repeated 4x across cluster]
# (objective pid=7680) Epoch [608/841] Loss: 1.73535 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.43276 [repeated 4x across cluster]
# (objective pid=7680) Epoch [612/841] Loss: 2.97594 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.15279 [repeated 4x across cluster]
# (objective pid=7680) Epoch [616/841] Loss: 0.92962 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 2.52256 [repeated 4x across cluster]
# (objective pid=7680) Epoch [620/841] Loss: 1.22810 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.38110 [repeated 4x across cluster]
# (objective pid=7680) Epoch [623/841] Loss: 1.13195 [repeated 3x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.77309 [repeated 4x across cluster]
# (objective pid=7680) Epoch [627/841] Loss: 0.60374 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.21032 [repeated 3x across cluster]
# (objective pid=7680) Epoch [631/841] Loss: 1.03784 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.18005 [repeated 4x across cluster]
# (objective pid=7680) Epoch [635/841] Loss: 0.66255 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.43705 [repeated 4x across cluster]
# (objective pid=7680) Epoch [639/841] Loss: 0.17787 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.49303 [repeated 4x across cluster]
# (objective pid=7680) Epoch [643/841] Loss: 6.74101 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.10837 [repeated 4x across cluster]
# (objective pid=7680) Epoch [647/841] Loss: 2.46084 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.27766 [repeated 4x across cluster]
# (objective pid=7680) Epoch [651/841] Loss: 1.87437 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.64372 [repeated 4x across cluster]
# (objective pid=7680) Epoch [654/841] Loss: 0.50547 [repeated 3x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 3.49270 [repeated 3x across cluster]
# (objective pid=7680) Epoch [658/841] Loss: 14.23195 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.89193 [repeated 4x across cluster]
# (objective pid=7680) Epoch [662/841] Loss: 0.76423 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.18987 [repeated 4x across cluster]
# (objective pid=7680) Epoch [666/841] Loss: 3.28640 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.89090 [repeated 4x across cluster]
# (objective pid=7680) Epoch [670/841] Loss: 0.70697 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.24739 [repeated 4x across cluster]
# (objective pid=7680) Epoch [674/841] Loss: 0.35562 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.66210 [repeated 4x across cluster]
# (objective pid=7680) Epoch [678/841] Loss: 2.19326 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.03395 [repeated 4x across cluster]
# (objective pid=7680) Epoch [682/841] Loss: 0.17914 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.59407 [repeated 4x across cluster]
# (objective pid=7680) Epoch [686/841] Loss: 0.17206 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.37364 [repeated 4x across cluster]
# (objective pid=7680) Epoch [690/841] Loss: 0.63822 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.20513 [repeated 4x across cluster]
# (objective pid=7680) Epoch [694/841] Loss: 5.86296 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 4.35741 [repeated 4x across cluster]
# (objective pid=7680) Epoch [698/841] Loss: 2.90659 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.02354 [repeated 4x across cluster]
# (objective pid=7680) Epoch [702/841] Loss: 2.39595 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.82465 [repeated 4x across cluster]
# (objective pid=7680) Epoch [706/841] Loss: 0.18159 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 2.64498 [repeated 4x across cluster]
# (objective pid=7680) Epoch [710/841] Loss: 2.68442 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.35202 [repeated 4x across cluster]
# (objective pid=7680) Epoch [714/841] Loss: 0.25737 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.68294 [repeated 4x across cluster]
# (objective pid=7680) Epoch [718/841] Loss: 0.17304 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.51524 [repeated 4x across cluster]
# (objective pid=7680) Epoch [722/841] Loss: 3.21100 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 6.38837 [repeated 4x across cluster]
# (objective pid=7680) Epoch [726/841] Loss: 0.93233 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.39972 [repeated 4x across cluster]
# (objective pid=7680) Epoch [730/841] Loss: 1.19852 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.46018 [repeated 4x across cluster]
# (objective pid=7680) Epoch [734/841] Loss: 1.21947 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.08430 [repeated 4x across cluster]
# (objective pid=7680) Epoch [738/841] Loss: 0.60075 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.51115 [repeated 4x across cluster]
# (objective pid=7680) Epoch [742/841] Loss: 0.78725 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.83580 [repeated 4x across cluster]
# (objective pid=7680) Epoch [746/841] Loss: 0.67607 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.96644 [repeated 4x across cluster]
# (objective pid=7680) Epoch [750/841] Loss: 0.36685 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 4.43856 [repeated 4x across cluster]
# (objective pid=7680) Epoch [754/841] Loss: 2.11888 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.28490 [repeated 4x across cluster]
# (objective pid=7680) Epoch [758/841] Loss: 1.22209 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 2.72882 [repeated 4x across cluster]
# (objective pid=7680) Epoch [762/841] Loss: 1.56664 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.30729 [repeated 4x across cluster]
# (objective pid=7680) Epoch [766/841] Loss: 1.12392 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.93326 [repeated 4x across cluster]
# (objective pid=7680) Epoch [770/841] Loss: 0.49249 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.63508 [repeated 4x across cluster]
# (objective pid=7680) Epoch [774/841] Loss: 0.05556 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.77036 [repeated 4x across cluster]
# (objective pid=7680) Epoch [778/841] Loss: 0.36920 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.90430 [repeated 4x across cluster]
# (objective pid=7680) Epoch [782/841] Loss: 1.26309 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.17419 [repeated 4x across cluster]
# (objective pid=7680) Epoch [786/841] Loss: 2.26630 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.70153 [repeated 4x across cluster]
# (objective pid=7680) Epoch [790/841] Loss: 1.23018 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.34855 [repeated 4x across cluster]
# (objective pid=7680) Epoch [794/841] Loss: 1.06742 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 4.39885 [repeated 4x across cluster]
# (objective pid=7680) Epoch [798/841] Loss: 0.37714 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.38997 [repeated 4x across cluster]
# (objective pid=7680) Epoch [802/841] Loss: 0.53730 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.71884 [repeated 4x across cluster]
# (objective pid=7680) Epoch [806/841] Loss: 0.51600 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.12367 [repeated 4x across cluster]
# (objective pid=7680) Epoch [810/841] Loss: 1.91944 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.53590 [repeated 4x across cluster]
# (objective pid=7680) Epoch [814/841] Loss: 0.85914 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.06734 [repeated 4x across cluster]
# (objective pid=7680) Epoch [818/841] Loss: 0.90959 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 2.07833 [repeated 4x across cluster]
# (objective pid=7680) Epoch [822/841] Loss: 0.27467 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.09309 [repeated 4x across cluster]
# (objective pid=7680) Epoch [826/841] Loss: 1.22575 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 6.36369 [repeated 4x across cluster]
# (objective pid=7680) Epoch [830/841] Loss: 0.70906 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.50640 [repeated 4x across cluster]
# (objective pid=7680) Epoch [834/841] Loss: 0.83428 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.07608 [repeated 4x across cluster]
# (objective pid=7680) Epoch [838/841] Loss: 0.43890 [repeated 4x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 0.13306 [repeated 4x across cluster]
# (objective pid=7680) MSE: 7269.9956,R2: -20.2052,RMSE: 85.2643, PCIP: 0.20,score_avg:-1010.1595
# (objective pid=7680) Epoch [841/841] Loss: 0.84607 [repeated 3x across cluster]
# (objective pid=7680) Epoch [842/841] Val Loss: 1.21386 [repeated 4x across cluster]
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name           </th><th style="text-align: right;">  mse</th><th style="text-align: right;">   pcip</th><th style="text-align: right;">      r2</th><th style="text-align: right;">   rmse</th><th style="text-align: right;">  score_avg</th><th>should_checkpoint  </th></tr>
# </thead>
# <tbody>
# <tr><td>objective_25c18_00008</td><td style="text-align: right;"> 9956</td><td style="text-align: right;">77.8109</td><td style="text-align: right;">-28.0398</td><td style="text-align: right;">99.7798</td><td style="text-align: right;">   -1363.08</td><td>True               </td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>

# %%
best_trials = analysis.get_best_trial("score_avg", "max", "all")
print(f"Best trial config: {best_trials.config}")
print(f"Best trial final validation mse: {best_trials.last_result['mse']}")
print(f"Best trial final validation r2: {best_trials.last_result['r2']}")
print(f"Best trial final validation rmse: {best_trials.last_result['rmse']}")
print(f"Best trial final validation pcip: {best_trials.last_result['pcip']}")
#print(f"Best trial final validation score_avg: {best_trials.last_result['optimal_dim']}")
#print(f"Best trial final validation l1_coef: {best_trial.last_result['l1_coef']}")
best_checkpoints = best_trials.checkpoint.to_air_checkpoint()
# Out:
# Best trial config: {'lr': 0.00011600353938883104, 'momentum': 0.009328857531182592, 'opt_momentum': 0.00918667445141735, 'weight_std': 0.0033244058597709614, 'weight_mean': 6.9949608597674535, 'bias_mean': 0.3226930394143123, 'bias_std': 0.012726759642886507, 'batch_size': 14, 'epochs': 490, 'dims': [8, 128, 16, 32, 8, 256, 28], 'optimiser': 'Adams', 'checkpoint_interval': 10}
# Best trial final validation mse: 405.47540283203125
# Best trial final validation r2: -0.18269383907318115
# Best trial final validation rmse: 20.136419811675342
# Best trial final validation pcip: 72.83582089552239

# %%
gpus_per_trial = 2
best_trained_model=BayesianCNN(num_feature=X_train.shape[1],dims=best_trials.config["dims"],
                           weight_std=best_trials.config["weight_std"],
                          bias_std=best_trials.config["bias_std"],
                               bias_mean=best_trials.config["bias_mean"],weight_mean=best_trials.config["weight_mean"])

device = "cpu"
if torch.cuda.is_available():
    device = "cuda:0"
    if gpus_per_trial > 1:
        best_trained_model = nn.DataParallel(best_trained_model)
best_trained_model.to(device)
with best_checkpoints.as_directory() as dir_path:
    print(dir_path)
    model_state, optimizer_state = torch.load(os.path.join(dir_path, "checkpoint.pt"))
    best_trained_model.load_state_dict(model_state)
best_checkpoint_data = best_checkpoints.to_dict()
# Out:
# C:\Users\omondiagbep\ray_results\pbt2_silt_2\objective_25c18_00015_15_batch_size=14,bias_mean=0.3227,bias_std=0.0127,epochs=490,lr=0.0001,momentum=0.0093,opt_momentum=0.0092,w_2023-11-24_12-15-11\checkpoint_000000

# %%
def train_func(model,optimizer_=None,n_epochs = 1000,batch_size = 16,lr=0.0001):
    loss_fn = nn.MSELoss()  # mean square error

    if optimizer_ is None:
        #Regularization helps prevent overfitting by penalizing large weights
        optimizer = torch.optim.Adam(model.parameters(),  lr=lr)
    if optimizer_ == Optimiser.RMSprop:
        optimizer = torch.optim.RMSprop(model.parameters(), momentum=0.0009, lr=lr)
    elif optimizer_ == Optimiser.LBFGS:
        optimizer = torch.optim.LBFGS(model.parameters(),  lr=lr)
    elif optimizer_ == Optimiser.Adams:
        optimizer = torch.optim.Adam(model.parameters(),  lr=lr)
    elif optimizer_ == Optimiser.SGD:
        optimizer = torch.optim.SGD(model.parameters(),  lr=lr,momentum=0.0009)
    elif optimizer_ == Optimiser.Nadam:
        optimizer = torch.optim.NAdam(model.parameters(),  lr=lr,momentum_decay=0.0009)



    # Hold the best model
    best_mse = np.inf # init to infinity

    history = []
    epochs_no_improve = 0

    early_stop=False
    n_epochs_stop = 40
    min_val_loss=float('inf')
    best_r2 = 0.0000
    best_pcip = 0.0000
    best_score_avg =0.0000
    criterion=nn.MSELoss()

    train = torch.utils.data.TensorDataset(X_train,y_train)
    val = torch.utils.data.TensorDataset(X_val,y_val)
    train_dataloader = DataLoader(train, batch_size=batch_size)
    val_dataloader = DataLoader(val, batch_size=batch_size)
    for epoch in range(n_epochs):
        model.train()
        train_loss =0
        val_loss=0

        for inputs, targets in train_dataloader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

        # Print the training loss for this epoch
        print(f"Epoch [{epoch+1}/{n_epochs}] Loss: {loss.item():.5f}")

        for inputs, targets in val_dataloader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            val_loss += loss.item()
            loss.backward()
            optimizer.step()

        # Print the training loss for this epoch
        avg_val_loss = val_loss / len(inputs)
        print(f"Epoch [{epoch+1}/{n_epochs}] Val Loss: {loss.item():.5f}")

        #at the start
        if avg_val_loss < min_val_loss:
            epochs_no_improve = 0
            min_val_loss = avg_val_loss
            print("restarting counter")
            print(epochs_no_improve)
        else:
            epochs_no_improve += 1
            print("increasing counter")
            print(epochs_no_improve)

        if epochs_no_improve == n_epochs_stop:
            print('Early stopping!')
            early_stop = True
            break
        # evaluate accuracy at end of each epoch
        model.eval()
        mse,r2,rmse,pcip = get_metrics(X_val,y_val,model)
        score_avg= ((r2*100)+pcip)/2
        print(f'r2: {r2:.4f}')
        print(f'pcip: {pcip:.4f}')
        y_pred = model(X_val)

        mse = loss_fn(y_pred, y_val)
        mse = float(mse)
        rmse= np.sqrt(mse)
        print(f'RMSE: {rmse:.4f}')
        history.append(rmse)
        if rmse < best_mse:
            best_mse = rmse

        if r2 > best_r2 :
            best_r2 = r2
            print("save rmse state")
            modelrmse_state_dict = model.state_dict()
        if pcip > best_pcip :
            best_pcip = pcip
            print("save pcip state")
            modelpcip_state_dict = model.state_dict()
        if score_avg  > best_score_avg:
            best_score_avg = score_avg
            print("save score avg state")
            modelscore_avg_state_dict = model.state_dict()

        if early_stop:
            print('Training stopped early.')


        print(f'Best RMSE so far: {best_mse:.4f}')
        print(f'Best r2 so far: {best_r2:.4f}')
        print(f'best_score_avg so far: {best_score_avg:.4f}')
        print(f'Best pcip so far: {best_pcip:.4f}')


    #modelrmse_state_dict.update(modelpcip_state_dict)

    # Load the updated state_dict back into model
    #model.load_state_dict(modelrmse_state_dict)
    model.load_state_dict(modelscore_avg_state_dict)
    #model_pcip=model.load_state_dict(modelpcip_state_dict)
    #model_r2=model.load_state_dict(modelrmse_state_dict)
    print("RMSE: %.2f" % best_mse)
    import matplotlib.pyplot as plt
    plt.plot(history)
    plt.show()
    return model,history,best_mse

# %% [markdown]
# ## Best architecture found

# %%
class BayesianCNN(nn.Module):
    def __init__(self, num_feature: int, dims=[512, 28, 64], bias_mean=0.0003,weight_mean=0.0002,weight_std=0.0001, bias_std=0.0005):
        super(BayesianCNN, self).__init__()

        # Define the fully connected layers based on the specified dimensions
        self.fc_layers = nn.ModuleList()
        in_dim = num_feature
        for out_dim in dims:
            self.fc_layers.append(nn.Linear(in_dim, out_dim))
            in_dim = out_dim

        self.fc_out = nn.Linear(in_dim, 1)  # Output layer for pret

        # Update the dimensions of weight_mu and weight_rho to match the output dimension
        self.weight_dim = out_dim
        self.weight_mu = nn.Parameter(torch.Tensor(1, self.weight_dim))
        self.weight_rho = nn.Parameter(torch.Tensor(1, self.weight_dim))

        self.bias_mu = nn.Parameter(torch.Tensor(1))
        self.bias_rho = nn.Parameter(torch.Tensor(1))
        self.weight_std = weight_std
        self.bias_std = bias_std
        self.weight_mean = weight_mean
        self.bias_mean = bias_mean

        # Initialize parameters
        self.reset_parameters()

    def reset_parameters(self):
        # Initialize weight means close to zero and standard deviations to be small
        nn.init.normal_(self.weight_mu, self.weight_mean, std=self.weight_std)
        nn.init.normal_(self.weight_rho, self.weight_mean, std=self.weight_std)

        # Initialize bias means close to zero and standard deviations to be small
        nn.init.normal_(self.bias_mu, self.bias_mean, std=self.bias_std)
        nn.init.normal_(self.bias_rho, self.bias_mean, std=self.bias_std)

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten the input

        # Pass through fully connected layers with specified dimensions
        for fc_layer in self.fc_layers:
            x = F.selu(fc_layer(x))
            #Dropout randomly deactivates a fraction of neurons during training,
            # which can help prevent overfitting.
            x = F.dropout(x,p=0.30)


        # Re-parameterization trick for sampling weights
        #To reduce variability, you can reduce the standard deviation of this sampling.
        weight_epsilon = Normal(0.0,1).sample(self.weight_mu.size())
        weight_sigma = torch.log(1 + torch.exp(self.weight_rho))
        weight = self.weight_mu + (weight_sigma * weight_epsilon)

        bias_epsilon = Normal(0.0,1).sample(self.bias_mu.size())
        bias_sigma = torch.log(1 + torch.exp(self.bias_rho))
        bias = self.bias_mu + (bias_sigma * bias_epsilon)

        # Enforce non-negativity on weights and biases
        weight = torch.clamp(weight, min=0)
        bias = torch.clamp(bias, min=0)


        # Final linear layer operation
        output = F.linear(x, weight, bias)
        # Apply sigmoid activation to squash values between 0 and 1
        output = torch.sigmoid(output)

        # Scale the values to the desired range (0 to 100)
        output = output * 100

        return output

# %%
from enum import Enum
class Optimiser(str, Enum):
    Adams = "Adams"
    SGD ="SGD"
    Adadelta = "Adadelta"
    Adagrad = "Adagrad"
    Adamax = "Adamax"
    Nadam = "Nadam"
    Ftrl = "Ftrl"
    RMSprop="RMSprop"
    LBFGS ="LBFGS"
    #LBFGS ="LBFGS"
    def __str__(self):
        return self.value
#fine tune if needed - not use

# %%
#Best trial config: {'lr': 0.00011600353938883104,
# 'momentum': 0.009328857531182592,
# 'opt_momentum': 0.00918667445141735, 'weight_std': 0.0033244058597709614,
# 'weight_mean': 6.9949608597674535, 'bias_mean': 0.3226930394143123, 'bias_std': 0.012726759642886507,
# 'batch_size': 14, 'epochs': 490, 'dims': [8, 128, 16, 32, 8, 256, 28], 'optimiser':
# 'Adams', 'checkpoint_interval': 10}
# otimiser': 'Adams', 'checkpoint_interval': 10,
# 'opt_momentum': 0.009262583085697922}


model_ = BayesianCNN(num_feature=X_train.shape[1],dims=[512,28,64,128,256],
                       weight_std=4.7621 ,weight_mean=0.0002, bias_mean=0.0003,
                      bias_std=16.738).to("cpu")


model,history,best_mse =train_func(model_,n_epochs=325,batch_size=66, lr=0.00012,optimizer_="Nadam")
# Out:
# Epoch [1/325] Loss: 2363.66943
# Epoch [1/325] Val Loss: 3392.47583
# restarting counter
# 0
# MSE: 2506.8718,R2: -6.4862,RMSE: 50.0687, PCIP: 12.42,score_avg:-318.1003
# r2: -6.4862
# pcip: 12.4172
# RMSE: 50.5759
# save pcip state
# Best RMSE so far: 50.5759
# Best r2 so far: 0.0000
# best_score_avg so far: 0.0000
# Best pcip so far:
# Best RMSE so far: 41.9348
# Best r2 so far: 0.0000
# best_score_avg so far: 0.0000
# Best pcip so far: 53.3113
# Epoch [142/325] Loss: 1723.84814
# Epoch [142/325] Val Loss: 1838.31567
# increasing counter
# 38
# MSE: 1839.2618,R2: -4.4925,RMSE: 42.8866, PCIP: 14.90,score_avg:-217.1756
# r2: -4.4925
# pcip: 14.9007
# RMSE: 43.7023
# Best RMSE so far: 41.9348
# Best r2 so far: 0.0000
# best_score_avg so far: 0.0000
# Best pcip so far: 53.3113
# Epoch [143/325] Loss: 1676.51489
# Epoch [143/325] Val Loss: 1862.68335
# increasing counter
# 39
# MSE: 1856.7386,R2: -4.5447,RMSE: 43.0899, PCIP: 17.05,score_avg:-218.7090
# r2: -4.5447
# pcip: 17.0530
# RMSE: 42.5145
# Best RMSE so far: 41.9348
# Best r2 so far: 0.0000
# best_score_avg so far: 0.0000
# Best pcip so far: 53.3113
# Epoch [144/325] Loss: 1679.13745
# Epoch [144/325] Val Loss: 1838.31567
# increasing counter
# 40
# Early stopping!
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[106], line 16
#       1 #Best trial config: {'lr': 0.00011600353938883104,
#       2 # 'momentum': 0.009328857531182592,
#       3 # 'opt_momentum': 0.00918667445141735, 'weight_std': 0.0033244058597709614,
#    (...)
#       7 # otimiser': 'Adams', 'checkpoint_interval': 10,
#       8 # 'opt_momentum': 0.009262583085697922}
#      11 model_ = BayesianCNN(num_feature=X_train.shape[1],dims=[512,28,64,128,256],
#      12                        weight_std=4.7621 ,weight_mean=0.0002, bias_mean=0.0003,
#      13                       bias_std=16.738).to("cpu")
# ---> 16 model,history,best_mse =train_func(model_,n_epochs=325,batch_size=66, lr=0.00012,optimizer_="Nadam")
#
# Cell In[105], line 123, in train_func(model, optimizer_, n_epochs, batch_size, lr)
#     116     print(f'Best pcip so far: {best_pcip:.4f}')
#     119 #modelrmse_state_dict.update(modelpcip_state_dict)
#     120
#     121 # Load the updated state_dict back into model
#     122 #model.load_state_dict(modelrmse_state_dict)
# --> 123 model.load_state_dict(modelscore_avg_state_dict)
#     124 #model_pcip=model.load_state_dict(modelpcip_state_dict)
#     125 #model_r2=model.load_state_dict(modelrmse_state_dict)
#     126 print("RMSE: %.2f" % best_mse)
#
# UnboundLocalError: local variable 'modelscore_avg_state_dict' referenced before assignment

# %%
#save model
best_model_name = f'mir_silt_model-1.0.1.pt'
torch.save(best_trained_model.state_dict(),os.path.join("../model-store/",best_model_name))

# %%
best_model_name = f'mir_silt_model-1.0.1.pt'
best_trained_model=torch.load(os.path.join("../model-store/",best_model_name))

# %%
class BayesianCNN(nn.Module):
    def __init__(self, num_feature: int, dims=[512, 28, 64], weight_std=0.001, bias_std=9.5):
        super(BayesianCNN, self).__init__()

        # Define the fully connected layers based on the specified dimensions
        self.fc_layers = nn.ModuleList()
        in_dim = num_feature
        for out_dim in dims:
            self.fc_layers.append(nn.Linear(in_dim, out_dim))
            in_dim = out_dim

        self.fc_out = nn.Linear(in_dim, 1)  # Output layer carbon

        # Update the dimensions of weight_mu and weight_rho to match the output dimension
        self.weight_dim = out_dim
        self.weight_mu = nn.Parameter(torch.Tensor(1, self.weight_dim))
        self.weight_rho = nn.Parameter(torch.Tensor(1, self.weight_dim))

        self.bias_mu = nn.Parameter(torch.Tensor(1))
        self.bias_rho = nn.Parameter(torch.Tensor(1))
        self.weight_std = weight_std
        self.bias_std = bias_std

        # Initialize parameters
        self.reset_parameters()

    def reset_parameters(self):
        # Initialize weight means close to zero and standard deviations to be small
        nn.init.normal_(self.weight_mu, mean=0.0002, std=self.weight_std)
        nn.init.normal_(self.weight_rho, mean=0.003, std=self.weight_std)

        # Initialize bias means close to zero and standard deviations to be small
        nn.init.normal_(self.bias_mu, mean=0.0003, std=self.bias_std)
        nn.init.normal_(self.bias_rho, mean=0.004, std=self.bias_std)

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten the input

        # Pass through fully connected layers with specified dimensions
        for fc_layer in self.fc_layers:
            x = F.rrelu(fc_layer(x))

        # Re-parameterization trick for sampling weights
        weight_epsilon = Normal(0, 1).sample(self.weight_mu.size())
        weight_sigma = torch.log(1 + torch.exp(self.weight_rho))
        weight = self.weight_mu + weight_sigma * weight_epsilon

        bias_epsilon = Normal(0, 1).sample(self.bias_mu.size())
        bias_sigma = torch.log(1 + torch.exp(self.bias_rho))
        bias = self.bias_mu + bias_sigma * bias_epsilon

        # Enforce non-negativity on weights and biases
        weight = torch.clamp(weight, min=0)
        bias = torch.clamp(bias, min=0)

        # Final linear layer operation
        output = F.linear(x, weight, bias)
        return output
model = BayesianCNN(num_feature=X_train.shape[1],dims=[8,32,32,256,128,8],
                     weight_std=0.0016,
                      bias_std=0.0015744)
model.load_state_dict(torch.load(os.path.join("../model-store/",best_model_name)))
# Out:
# <All keys matched successfully>

# %%
## Testing
model.eval()
with torch.no_grad():
    # Test out inference with 5 samples
    for i in range(5):
        X_sample = X_test_raw[i: i+1]
        X_sample = scaler.transform(X_sample)
        X_sample = torch.tensor(X_sample, dtype=torch.float32)
        y_pred = model(X_sample)


        print(f"{y_pred.numpy()} (expected {y_test[i].numpy()})")
# Out:
# [[50.]] (expected [53.870003])
# [[50.]] (expected [45.39])
# [[50.]] (expected [23.483])
# [[50.]] (expected [49.93])
# [[61.293297]] (expected [62.72])

# %%
test_result= evaluate_soil_property(model,X_test_raw,sample_size=100)
test_result["obs"] = y_test
test_result['type'] ='Validation'
test_result['variable'] ='silt'
test_result
# Out:
#           lower      upper       pred        obs        type variable
# 0     47.158550  52.344547  49.751549  53.870003  Validation     silt
# 1     47.905582  53.466183  50.685883  45.389999  Validation     silt
# 2     22.208994  30.603739  26.406366  23.483000  Validation     silt
# 3     50.453918  56.851082  53.652500  49.930000  Validation     silt
# 4     56.142601  64.825912  60.484257  62.720001  Validation     silt
# ...         ...        ...        ...        ...         ...      ...
# 1000  21.466299  30.006056  25.736177  20.000000  Validation     silt
# 1001  45.636993  50.432243  48.034618  47.090000  Validation     silt
# 1002  72.831245  84.389931  78.610588  58.130001  Validation     silt
# 1003  35.726421  40.607563  38.166992  47.040001  Validation     silt
# 1004  53.154293  60.797016  56.975655  54.000000  Validation     silt
#
# [1005 rows x 6 columns]

# %%
test_result['pred'].max()
# Out:
# 90.167206

# %%
train_result= evaluate_soil_property(model,X_train_raw,sample_size=1000)
train_result["obs"] = y_train
train_result['type'] =' Calibration'
train_result['variable'] ='silt'
train_result
# Out:
#           lower      upper       pred        obs          type variable
# 0     34.515549  40.581673  37.548611  42.860001   Calibration     silt
# 1     34.676460  40.388390  37.532425  39.750000   Calibration     silt
# 2     41.648617  46.013294  43.830956  49.770000   Calibration     silt
# 3     46.729786  51.681400  49.205593  40.260002   Calibration     silt
# 4     49.905277  55.677021  52.791149  57.510002   Calibration     silt
# ...         ...        ...        ...        ...           ...      ...
# 2407  45.731281  50.522625  48.126953  46.369999   Calibration     silt
# 2408  12.083541  22.105232  17.094387  16.000000   Calibration     silt
# 2409  48.585258  54.210403  51.397831  48.000000   Calibration     silt
# 2410  11.073594  21.036007  16.054800  14.510000   Calibration     silt
# 2411  58.409973  67.596573  63.003273  61.000000   Calibration     silt
#
# [2412 rows x 6 columns]

# %%
final_df=pd.merge(train_result,test_result,how="outer")

# %%
final_df.to_csv("C:/Projects/ResearchProjects/Research-SoilSpectroscopy/Smap/Models/CNN/Mir/Results/cnn_silt.csv")
final_df
# Out:
#           lower      upper       pred        obs          type variable
# 0     34.515549  40.581673  37.548611  42.860001   Calibration     silt
# 1     34.676460  40.388390  37.532425  39.750000   Calibration     silt
# 2     41.648617  46.013294  43.830956  49.770000   Calibration     silt
# 3     46.729786  51.681400  49.205593  40.260002   Calibration     silt
# 4     49.905277  55.677021  52.791149  57.510002   Calibration     silt
# ...         ...        ...        ...        ...           ...      ...
# 3412  21.466299  30.006056  25.736177  20.000000    Validation     silt
# 3413  45.636993  50.432243  48.034618  47.090000    Validation     silt
# 3414  72.831245  84.389931  78.610588  58.130001    Validation     silt
# 3415  35.726421  40.607563  38.166992  47.040001    Validation     silt
# 3416  53.154293  60.797016  56.975655  54.000000    Validation     silt
#
# [3417 rows x 6 columns]

# %%
import numpy as np

def calculate_pcip(y_true, lower_bounds, upper_bounds):
    num_samples = len(y_true)
    num_covering_intervals = np.sum((lower_bounds <= y_true) & (y_true <= upper_bounds))
    pcip = (num_covering_intervals / num_samples) * 100
    return pcip

pcip = calculate_pcip(test_result['obs'], test_result['lower'], test_result['upper'])
print(f"Prediction Interval Coverage Probability (PCIP): {pcip:.2f}%")
# Out:
# Prediction Interval Coverage Probability (PCIP): 43.38%

# %%
#mean predition interval width
def calculate_mpiw(lower_bounds, upper_bounds):
    num_samples = len(lower_bounds)
    num_covering_intervals = np.sum(upper_bounds -lower_bounds)
    mpiw = (num_covering_intervals / num_samples)
    return mpiw

mpiw = calculate_mpiw(test_result['lower'], test_result['upper'])
print(f"Mean Prediction Interval Width (mpiw): {mpiw:.2f}")
# Out:
# Mean Prediction Interval Width (mpiw): 7.23

# %%
evaluate(model,X_train_raw,y_train,type="r2")
# Out:
# 0.9293853932338337

# %%
evaluate(model,X_test_raw,y_test,type="r2")
# Out:
# 0.7783451010878523

# %%
evaluate(model,X_test_raw,y_test,type="rmse")
# Out:
# 8.731834

# %%
evaluate(model,X_train_raw,y_train,type="rmse")
# Out:
# 4.9056954
